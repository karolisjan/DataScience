# %% [markdown]
# # Quantopian Basics

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Getting Information

# %%
mcd = get_pricing(
    'MCD',
    start_date='2005-01-01',
    end_date='2018-01-01',
    frequency='daily'
)

# %%
mcd['close_price'].plot(
    figsize=(20, 10),
    fontsize=20,
)

plt.title('MCD', fontsize=20)
plt.legend(fontsize=20);

# %%
mcd['close_price'].pct_change(1).hist(
    bins=100,
    figsize=(20, 10),
);
