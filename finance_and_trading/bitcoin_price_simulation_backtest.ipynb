# %% [markdown]
# # Backtest of BTC-USD Monte Carlo Simulation for 2017

# %%
import quandl
import warnings
import numpy as np
import pandas as pd
import datetime as dt
import scipy.stats as stats
import matplotlib.pyplot as plt
from IPython.core.display import display, HTML

# %%
warnings.filterwarnings('ignore')
plt.rcParams['font.size'] = 20
np.random.seed = 42

# %%
btc = quandl.get('BCHARTS/BITSTAMPUSD')
btc = btc['2015-01-01':]
btc_past = btc[:'2017-01-01']
btc_future = btc['2017-01-01':]

# %%
btc.replace(0, np.nan, inplace=True)

btc_past[[
    'Close',
]].plot(
    figsize=(20, 10),
    logy=True
)

plt.title('BTC-USD 2015-2017')
plt.ylabel('BTC-USD (log scale)')
plt.legend();

# %%
btc.replace(0, np.nan, inplace=True)

btc_future[[
    'Close',
]].plot(
    figsize=(20, 10),
    logy=True
)

plt.title('BTC-USD 2017')
plt.ylabel('BTC-USD (log scale)')
plt.legend();

# %%
btc_past['Daily Return'] = (btc_past['Close'].pct_change()).fillna(0)
btc_past['Log Daily Return'] = btc_past['Daily Return'].apply(lambda x: np.log(1 + x))

display(btc_past.head())

btc_past[['Log Daily Return']].hist(
    bins=100,
    figsize=(20, 10),
    alpha=0.5
);
# Out:
#               Open    High     Low   Close  Volume (BTC)  Volume (Currency)  \
# Date
# 2015-01-01  321.00  321.00  312.60  313.81   3087.436554       9.745096e+05
# 2015-01-02  313.82  317.01  311.96  315.42   3468.281375       1.092446e+06
# 2015-01-03  315.42  316.58  280.00  282.00  21752.719146       6.475952e+06
# 2015-01-04  280.00  289.39  255.00  264.00  41441.278553       1.126676e+07
# 2015-01-05  264.55  280.00  264.07  276.80   9528.271002       2.596898e+06
#
#             Weighted Price  Daily Return  Log Daily Return
# Date
# 2015-01-01      315.637119      0.000000          0.000000
# 2015-01-02      314.981849      0.005130          0.005117
# 2015-01-03      297.707695     -0.105954         -0.111998
# 2015-01-04      271.872950     -0.063830         -0.065958
# 2015-01-05      272.546601      0.048485          0.047346

# %%
std = btc_past['Log Daily Return'].std()
drift = btc_past['Log Daily Return'].mean() - 0.5 * btc_past['Log Daily Return'].var()

# %% [markdown]
# $$ \text{daily_returns} = e^{r} $$
#
# $$ r = drift + stdev * z $$

# %%
future_index = pd.date_range(start='2017-01-01', end=dt.date.today())
t_intervals = len(future_index)
iterations = 100000

simulated_daily_returns = np.exp(
    drift + std * stats.norm.ppf(
        np.random.rand(t_intervals, iterations)
    )
)

# %%
S = np.zeros_like(simulated_daily_returns)
S[0] = btc_past['Close'][-1]

for t in range(1, len(S)):
    S[t] = S[t - 1] * simulated_daily_returns[t]

# %%
pd.DataFrame(
    np.array([
        np.min(S, axis=1),
        np.mean(S, axis=1),
        np.max(S, axis=1),
    ]).T,
    columns=['Simulated Min', 'Simulated Mean', 'Simulated Max'],
    index=future_index
).plot(
    figsize=(20, 10),
    logy=True
)

btc_future['Close'].plot(label='Close')

plt.title('BTC-USD Simulation (n = 1e5)')
plt.ylabel('BTC-USD Close (log scale)')
plt.xlabel('Day')
plt.legend();

# %%
plt.figure(figsize=(20, 10))

plt.hist(S[-1], bins=1000, density=True)
plt.axvline(btc_future['Close'][-1], c='red', label='True')
plt.axvline(S[-1].mean(), c='green', label='Simulated Mean')
plt.xscale('log')
plt.title('Simulated prices for 2018-02-11')
plt.ylabel('Density')
plt.xlabel('BTC-USD Close (log scale)')
plt.legend()
plt.tight_layout()
plt.show();
